# %%
import pandas as pd
import os

# %%
companies = {
    # Công nghệ
    "FPT": "FPT",
    "CTCP Bán lẻ Kỹ thuật số FPT": "FRT",
    "CTCP Thế giới Di động": "MWG",
    "CTCP Tập đoàn Masan (có đầu tư vào tech)": "MSN",
    "CTCP Công nghệ Viễn thông Sài Gòn": "SGT",
    "CTCP Tập đoàn CMC": "CMG",
    "CTCP Công nghệ Viễn thông Elcom": "ELC",
    "CTCP Giải pháp Công nghệ Thông minh ITD": "ITD",
    "CTCP Tư vấn Đầu tư và Phát triển Tin học": "ITC",
    "CTCP Dịch vụ Trực tuyến NetNam": "NET",
    "CTCP VTC Dịch vụ truyền hình số": "VTC",
    "CTCP Công nghệ Truyền thông DTT": "DTT"
}

# %%
# Khởi tạo list chứa dữ liệu từng công ty
all_data = []

# Đọc từng file và gắn mã công ty
for full_name, ticker in companies.items():
    file_path = f"pre-processing/{full_name}_data.csv"
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)

        # Thêm mã công ty
        df["company_id"] = ticker

        # Chuyển cột thời gian nếu có
        if "quarter" in df.columns:
            df["quarter"] = pd.to_datetime(df["quarter"])

        all_data.append(df)
    else:
        print(f"⚠️ File không tồn tại: {file_path}")

# Gộp toàn bộ dữ liệu
df_all = pd.concat(all_data, ignore_index=True)

# Sắp xếp theo thời gian và công ty
df_all = df_all.sort_values(["company_id", "quarter"])

# Tạo biến mục tiêu P(t+1)
df_all["P_t_plus_1"] = df_all.groupby("company_id")["P"].shift(-1)

# Xoá dòng thiếu dữ liệu đầu vào
df_model = df_all.dropna(subset=["P_t_plus_1", "P/E", "EPS", "D/E", "SIZE"])

df_model.set_index(['company_id', 'quarter'], inplace=True)

df_model
# Out:
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
# C:\Users\hype1\AppData\Local\Temp\ipykernel_18812\3346459644.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["quarter"] = pd.to_datetime(df["quarter"])
#                                P       EPS       D/E          P/E       SIZE  \
# company_id quarter
# CMG        2019-01-01  11.601049  0.011923  1.919703   972.972506  29.026188
#            2019-04-01  14.099273  0.048975  1.091678   287.887901  29.173268
#            2019-07-01  15.946253  0.053388  1.114673   298.686256  29.159926
#            2020-01-01  15.810703  0.028354  1.161685   557.627110  29.232046
#            2020-04-01  18.514930  0.046744  1.141679   396.088869  29.250348
# ...                          ...       ...       ...          ...        ...
# VTC        2023-07-01  68.742055 -0.060655  2.533830 -1133.323962  26.153161
#            2023-10-01  68.907552  0.108404  1.953691   635.652921  26.330359
#            2024-01-01  72.241749 -0.141976  2.315512  -508.829017  26.218816
#            2024-04-01  72.052796 -0.137298  3.213035  -524.790144  26.281220
#            2024-07-01  75.210754 -0.032485  2.798950 -2315.254861  26.162527
#
#                        P_t_plus_1
# company_id quarter
# CMG        2019-01-01   14.099273
#            2019-04-01   15.946253
#            2019-07-01   16.045266
#            2020-01-01   18.514930
#            2020-04-01   24.101019
# ...                           ...
# VTC        2023-07-01   68.907552
#            2023-10-01   72.241749
#            2024-01-01   72.052796
#            2024-04-01   75.210754
#            2024-07-01   75.473572
#
# [166 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Giả sử df_model là DataFrame chứa dữ liệu của bạn
# Khởi tạo StandardScaler
scaler = StandardScaler()

# Chuẩn hóa toàn bộ DataFrame
df_model_scaled = df_model.copy()  # Tạo bản sao để không thay đổi dữ liệu gốc
df_model_scaled[:] = scaler.fit_transform(df_model)

# Kiểm tra lại dữ liệu đã chuẩn hóa
df_model_scaled
# Out:
#                               P       EPS       D/E       P/E      SIZE  \
# company_id quarter
# CMG        2019-01-01 -0.435036 -0.412435  0.053229 -0.099970  0.018952
#            2019-04-01 -0.434880  0.003029 -0.560228 -0.100007  0.102127
#            2019-07-01 -0.434764  0.052514 -0.543192 -0.100007  0.094582
#            2020-01-01 -0.434773 -0.228201 -0.508362 -0.099993  0.135366
#            2020-04-01 -0.434604 -0.021981 -0.523184 -0.100001  0.145717
# ...                         ...       ...       ...       ...       ...
# VTC        2023-07-01 -0.431467 -1.226269  0.508214 -0.100084 -1.605773
#            2023-10-01 -0.431457  0.669421  0.078409 -0.099989 -1.505566
#            2024-01-01 -0.431248 -2.138136  0.346470 -0.100051 -1.568645
#            2024-04-01 -0.431260 -2.085679  1.011416 -0.100051 -1.533354
#            2024-07-01 -0.431063 -0.910390  0.704633 -0.100149 -1.600477
#
#                        P_t_plus_1
# company_id quarter
# CMG        2019-01-01   -0.434916
#            2019-04-01   -0.434809
#            2019-07-01   -0.434803
#            2020-01-01   -0.434659
#            2020-04-01   -0.434334
# ...                           ...
# VTC        2023-07-01   -0.431728
#            2023-10-01   -0.431534
#            2024-01-01   -0.431545
#            2024-04-01   -0.431362
#            2024-07-01   -0.431346
#
# [166 rows x 6 columns]

# %%
from linearmodels.panel import PooledOLS
import statsmodels.api as sm

# Thiết lập biến phụ thuộc và biến độc lập
y = df_model_scaled['P_t_plus_1']  # Biến mục tiêu (giá cổ phiếu t+1)
X = df_model_scaled[['P/E', 'EPS', 'D/E', 'SIZE']]  # Các biến độc lập

# Thêm hằng số vào mô hình (intercept)
X = sm.add_constant(X)

# Áp dụng mô hình Pooled OLS
pooled_model = PooledOLS(y, X)
pooled_results = pooled_model.fit(cov_type="robust")

# In kết quả ước lượng
pooled_results
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:             P_t_plus_1   R-squared:                        0.1222
# Estimator:                  PooledOLS   R-squared (Between):              0.1443
# No. Observations:                 166   R-squared (Within):              -0.1141
# Date:                Fri, May 09 2025   R-squared (Overall):              0.1222
# Time:                        08:55:08   Log-likelihood                   -224.72
# Cov. Estimator:                Robust
#                                         F-statistic:                      5.6058
# Entities:                          11   P-value                           0.0003
# Avg Obs:                       15.091   Distribution:                   F(4,161)
# Min Obs:                       6.0000
# Max Obs:                       22.000   F-statistic (robust):             12.027
#                                         P-value                           0.0000
# Time periods:                      23   Distribution:                   F(4,161)
# Avg Obs:                       7.2174
# Min Obs:                       5.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const       1.333e-15     0.0738  1.806e-14     1.0000     -0.1458      0.1458
# P/E            0.0444     0.0110     4.0348     0.0001      0.0227      0.0662
# EPS            0.0491     0.0590     0.8317     0.4068     -0.0675      0.1657
# D/E           -0.2469     0.0546    -4.5215     0.0000     -0.3547     -0.1391
# SIZE           0.2877     0.1046     2.7509     0.0066      0.0812      0.4942
# ==============================================================================
# PanelResults, id: 0x23583a27110

# %%
from linearmodels.panel import PanelOLS
import statsmodels.api as sm

# Thiết lập biến phụ thuộc và biến độc lập
y = df_model_scaled['P_t_plus_1']  # Biến mục tiêu (giá cổ phiếu t+1)
X = df_model_scaled[['P/E', 'EPS', 'D/E', 'SIZE']]  # Các biến độc lập

# Thêm hằng số vào mô hình (intercept)
X = sm.add_constant(X)

# Áp dụng mô hình Fixed Effects (FEM)
fixed_effects_model = PanelOLS(y, X, entity_effects=True)  # entity_effects=True để có hiệu ứng cố định theo công ty
fixed_effects_results = fixed_effects_model.fit(cov_type="robust")

# In kết quả ước lượng
fixed_effects_results
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:             P_t_plus_1   R-squared:                        0.1113
# Estimator:                   PanelOLS   R-squared (Between):             -0.2554
# No. Observations:                 166   R-squared (Within):               0.1113
# Date:                Fri, May 09 2025   R-squared (Overall):             -0.3232
# Time:                        08:55:08   Log-likelihood                   -35.016
# Cov. Estimator:                Robust
#                                         F-statistic:                      4.7272
# Entities:                          11   P-value                           0.0013
# Avg Obs:                       15.091   Distribution:                   F(4,151)
# Min Obs:                       6.0000
# Max Obs:                       22.000   F-statistic (robust):             4.8918
#                                         P-value                           0.0010
# Time periods:                      23   Distribution:                   F(4,151)
# Avg Obs:                       7.2174
# Min Obs:                       5.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const       4.387e-15     0.0243  1.804e-13     1.0000     -0.0480      0.0480
# P/E           -0.0032     0.0095    -0.3407     0.7338     -0.0221      0.0156
# EPS           -0.0097     0.0118    -0.8289     0.4084     -0.0330      0.0135
# D/E           -0.1001     0.0600    -1.6693     0.0971     -0.2186      0.0184
# SIZE           0.9085     0.2252     4.0345     0.0001      0.4636      1.3534
# ==============================================================================
#
# F-test for Poolability: 133.36
# P-value: 0.0000
# Distribution: F(10,151)
#
# Included effects: Entity
# PanelEffectsResults, id: 0x23583a60080

# %%
from linearmodels.panel import RandomEffects
import statsmodels.api as sm

# Thiết lập biến phụ thuộc và biến độc lập
y = df_model_scaled['P_t_plus_1']  # Biến mục tiêu (giá cổ phiếu t+1)
X = df_model_scaled[['P/E', 'EPS', 'D/E', 'SIZE']]  # Các biến độc lập

# Thêm hằng số vào mô hình (intercept)
X = sm.add_constant(X)

# Áp dụng mô hình Random Effects
random_effects_model = RandomEffects(y, X)
random_effects_results = random_effects_model.fit(cov_type="robust")

# In kết quả ước lượng
random_effects_results
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:             P_t_plus_1   R-squared:                        0.0994
# Estimator:              RandomEffects   R-squared (Between):             -0.1103
# No. Observations:                 166   R-squared (Within):               0.1085
# Date:                Fri, May 09 2025   R-squared (Overall):             -0.1598
# Time:                        08:55:08   Log-likelihood                   -39.845
# Cov. Estimator:                Robust
#                                         F-statistic:                      4.4412
# Entities:                          11   P-value                           0.0020
# Avg Obs:                       15.091   Distribution:                   F(4,161)
# Min Obs:                       6.0000
# Max Obs:                       22.000   F-statistic (robust):             3.6837
#                                         P-value                           0.0067
# Time periods:                      23   Distribution:                   F(4,161)
# Avg Obs:                       7.2174
# Min Obs:                       5.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0290     0.4499     0.0644     0.9487     -0.8595      0.9175
# P/E           -0.0014     0.0116    -0.1245     0.9011     -0.0244      0.0215
# EPS           -0.0064     0.0122    -0.5223     0.6022     -0.0304      0.0177
# D/E           -0.0679     0.0630    -1.0779     0.2827     -0.1922      0.0565
# SIZE           0.7475     0.2346     3.1863     0.0017      0.2842      1.2108
# ==============================================================================
# RandomEffectsResults, id: 0x23583a92870

# %%
fixed_effects_results.f_statistic
# Out:
# Model F-statistic (homoskedastic)
# H0: All parameters ex. constant are zero
# Statistic: 4.7272
# P-value: 0.0013
# Distributed: F(4,151)
# WaldTestStatistic, id: 0x23581a08650

# %%
import numpy as np
import pandas as pd
from linearmodels.panel import PanelOLS, RandomEffects
from statsmodels.stats.stattools import durbin_watson
import scipy.linalg as la

# Lấy các hệ số ước lượng và phương sai-covariance của các mô hình
beta_FE = fixed_effects_results.params
beta_RE = random_effects_results.params
var_FE = fixed_effects_results.cov
var_RE = random_effects_results.cov

# Tính toán kiểm định Hausman
diff = beta_FE - beta_RE
diff_cov = var_FE - var_RE

# Kiểm tra tính khả thi của ma trận khác biệt và tính toán giá trị kiểm định Hausman
hausman_stat = diff.T @ la.inv(diff_cov) @ diff
df = len(beta_FE)  # số bậc tự do (số biến độc lập)

# P-value sử dụng phân phối Chi-squared
from scipy.stats import chi2
p_value = 1 - chi2.cdf(hausman_stat, df)

print(f"Hausman Statistic: {hausman_stat}")
print(f"P-value: {p_value}")
# Out:
# Hausman Statistic: 43.668080978632226
# P-value: 2.7048466022527862e-08

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Thêm hằng số vào các biến độc lập
X = add_constant(df_model_scaled[['P/E', 'EPS', 'D/E', 'SIZE']])

# Tính VIF cho từng biến độc lập
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# In kết quả
print(vif_data)
# Out:
#   Variable       VIF
# 0    const  1.000000
# 1      P/E  1.011531
# 2      EPS  1.071793
# 3      D/E  1.077664
# 4     SIZE  1.130049

# %%
from statsmodels.stats.stattools import durbin_watson

# Kiểm tra tự tương quan cho mô hình Pooled OLS
pooled_resids = pooled_results.resids
print(f'Durbin-Watson statistic for Pooled OLS: {durbin_watson(pooled_resids)}')

# Kiểm tra tự tương quan cho mô hình FEM
fixed_effects_resids = fixed_effects_results.resids
print(f'Durbin-Watson statistic for FEM: {durbin_watson(fixed_effects_resids)}')

# Kiểm tra tự tương quan cho mô hình REM
random_effects_resids = random_effects_results.resids
print(f'Durbin-Watson statistic for REM: {durbin_watson(random_effects_resids)}')
# Out:
# Durbin-Watson statistic for Pooled OLS: 0.24013475123607114
# Durbin-Watson statistic for FEM: 0.637450605585243
# Durbin-Watson statistic for REM: 0.5990977510826135

# %%
from statsmodels.stats.diagnostic import het_breuschpagan

# Format kết quả kiểm định
labels = ['LM Statistic', 'LM P-value', 'F-statistic', 'F-statistic P-value']

# Kiểm tra phương sai của sai số thay đổi cho mô hình Pooled OLS
pooled_bp_test = het_breuschpagan(pooled_resids, X)

print("\n📊 Breusch-Pagan test for Pooled OLS:")
for label, value in zip(labels, pooled_bp_test):
    print(f"{label:<25}: {value:.4f}")

## Kiểm tra phương sai của sai số thay đổi cho mô hình FEM
fixed_effects_bp_test = het_breuschpagan(fixed_effects_resids, X)

print("\n📊 Breusch-Pagan test for FEM:")
for label, value in zip(labels, fixed_effects_bp_test):
    print(f"{label:<25}: {value:.4f}")

# Kiểm tra phương sai của sai số thay đổi cho mô hình REM
random_effects_bp_test = het_breuschpagan(random_effects_resids, X)

print("\n📊 Breusch-Pagan test for REM:")
for label, value in zip(labels, random_effects_bp_test):
    print(f"{label:<25}: {value:.4f}")
# Out:
# 📊 Breusch-Pagan test for Pooled OLS:
# LM Statistic             : 26.3715
# LM P-value               : 0.0000
# F-statistic              : 7.6020
# F-statistic P-value      : 0.0000
#
# 📊 Breusch-Pagan test for FEM:
# LM Statistic             : 15.5447
# LM P-value               : 0.0037
# F-statistic              : 4.1585
# F-statistic P-value      : 0.0031
#
# 📊 Breusch-Pagan test for REM:
# LM Statistic             : 14.5794
# LM P-value               : 0.0057
# F-statistic              : 3.8754
# F-statistic P-value      : 0.0049

# %%
from statsmodels.stats.diagnostic import het_white

# Format kết quả kiểm định
labels = ['LM Statistic', 'LM P-value', 'F-statistic', 'F-statistic P-value']

# Kiểm tra phương sai của sai số thay đổi cho mô hình Pooled OLS
pooled_white_test = het_white(pooled_resids, X)

print("\n📊 White test for Pooled OLS:")
for label, value in zip(labels, pooled_white_test):
    print(f"{label:<25}: {value:.4f}")

## Kiểm tra phương sai của sai số thay đổi cho mô hình FEM
fixed_effects_white_test = het_white(fixed_effects_resids, X)

print("\n📊 White test for FEM:")
for label, value in zip(labels, fixed_effects_white_test):
    print(f"{label:<25}: {value:.4f}")

# Kiểm tra phương sai của sai số thay đổi cho mô hình REM
random_effects_white_test = het_white(random_effects_resids, X)

print("\n📊 White test for REM:")
for label, value in zip(labels, random_effects_white_test):
    print(f"{label:<25}: {value:.4f}")
# Out:
# 📊 White test for Pooled OLS:
# LM Statistic             : 140.8727
# LM P-value               : 0.0000
# F-statistic              : 60.4685
# F-statistic P-value      : 0.0000
#
# 📊 White test for FEM:
# LM Statistic             : 122.5026
# LM P-value               : 0.0000
# F-statistic              : 30.3760
# F-statistic P-value      : 0.0000
#
# 📊 White test for REM:
# LM Statistic             : 125.3828
# LM P-value               : 0.0000
# F-statistic              : 33.2948
# F-statistic P-value      : 0.0000
